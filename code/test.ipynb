# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(10, 7))
plt.plot([-4, -3, -2, -1, 0, 1, 2], [ 4.0313503,   2.73665762,  5.67925981, 11.62968632, 18.22053733, 22.11022149, 23.41683782], label="Lomax")
plt.plot([-4, -3, -2, -1, 0, 1, 2], [3.00139656e+01, 1.42943087e+01, 5.15987567e+00, 7.18047464e-01,
 1.48697287e-02, 3.09789416e-01, 4.92508885e-01], label="GEV")
plt.plot([-4, -3, -2, -1, 0, 1, 2], [ 2.33204107,  1.29881526,  2.60360001,  5.80324707, 10.16613034, 13.29507414,
 14.46533317], label="T-Student")
plt.plot([-4, -3, -2, -1, 0, 1, 2],  [ 3.87285032,  2.63971052,  5.65509088, 12.22259763, 20.47844759, 26.20655871
, 28.49653425], label="Frechet")

plt.xlabel("$\log_{10}(|\lambda|)$")
plt.ylabel("MSE")
plt.grid()
plt.legend()
plt.savefig("effect.svg", format="svg")

# %%
import pickle

# %%
data = pickle.load(open('../data/cifar-10-batches-py/bandit_data_sampled_1_test.pkl', 'rb'))

# %%
data[0, 3082:3092]
# Out:
# array([0.02471071, 0.03494623, 0.04280021, 0.49421426, 0.05525483,
#        0.06052864, 0.0653784 , 0.06989245, 0.07413214, 0.07814214])
