# %%
x = """87.05/0.01
89.11/0.10
-
-
89.03/0.16"""

# %%
y = '$' + x.replace('/', '\pm ').replace('\n', '$ & $') + '$'
print(y)
# Out:
# $87.05\pm 0.01$ & $89.11\pm 0.10$ & $-$ & $-$ & $89.03\pm 0.16$

# %%
# Out:
# $91.41\pm 0.16$ & $92.42\pm 0.12$ & $-$ & $-$ & $92.65\pm 0.04$

# %%
import pandas as pd

# %%
df = pd.read_csv('res_cifar.csv', header=None, sep='\t')

# %%
df
# Out:
#             0            1            2            3           4   \
# 0  84.63333333  84.79333333  85.05666667  83.03333333       85.01
# 1  84.24666667  84.50333333  85.52666667        84.34        84.6
# 2            -   79.23/0.30   58.04/5.47   51.84/0.92  17.12/0.97
# 3            -   78.74/0.56   54.12/0.51   46.24/0.41  21.63/1.44
# 4        86.82        71.36  67.95666667  52.78333333       27.39
#
#             5                   6            7            8            9   \
# 0  77.52666667               76.46  76.95666667        74.13  73.57333333
# 1        69.53               64.24        63.19  58.31333333  51.13666667
# 2            -  .../... 62.98/0.81      .../...      .../...            -
# 3            -             .../...    46.35/0.1      .../...      .../...
# 4  70.11666667         58.33666667  30.02666667        24.68  15.81333333
#
#           10          11          12          13          14           15  \
# ...

# %%
for i in range(1, 20):
    print(list(df[i]))
# Out:
# ['84.79333333', '84.50333333', '79.23/0.30', '78.74/0.56', '71.36']
# ['85.05666667', '85.52666667', '58.04/5.47', '54.12/0.51', '67.95666667']
# ['83.03333333', '84.34', '51.84/0.92', '46.24/0.41', '52.78333333']
# ['85.01', '84.6', '17.12/0.97', '21.63/1.44', '27.39']
# ['77.52666667', '69.53', '-', '-', '70.11666667']
# ['76.46', '64.24', '.../... 62.98/0.81', '.../...', '58.33666667']
# ['76.95666667', '63.19', '.../...', '46.35/0.1', '30.02666667']
# ['74.13', '58.31333333', '.../...', '.../...', '24.68']
# ['73.57333333', '51.13666667', '-', '.../...', '15.81333333']
# ['75.58', '79.82', '71.9/0.14', '-', '78.8']
# ['75.08', '64.39', '55.38/3.63', '16.19/0.99', '68.92']
# ['69.4', '48.44', '51.15/0.64', '44.60/0.19', '50.38']
# ['69.81', '43', '32.61/1.14', '35.87/1.11', '21.19']
# ['65.67', '37.8', '-', '20.66/5.74', '13.78']
# ['47.67666667', '64.33666667', '47.69/0.63', '-', '55.26666667']
# ['46.95', '50.11666667', '32.91/6.95', '41.45/9.93', '36.78666667']
# ...
